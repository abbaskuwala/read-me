# %%
import pandas as pd

# %%
pd.read_csv("cars.csv practice")
# Out:
#             Make      Model        Variant Ex-Showroom_Price Displacement  \
# 0           Tata  Nano Genx             Xt      Rs. 2,92,667       624 cc
# 1           Tata  Nano Genx             Xe      Rs. 2,36,447       624 cc
# 2           Tata  Nano Genx        Emax Xm      Rs. 2,96,661       624 cc
# 3           Tata  Nano Genx            Xta      Rs. 3,34,768       624 cc
# 4           Tata  Nano Genx             Xm      Rs. 2,72,223       624 cc
# ...          ...        ...            ...               ...          ...
# 1271       Honda       City   Vx Mt Diesel     Rs. 13,02,000      1498 cc
# 1272       Honda       City   Zx Mt Diesel     Rs. 14,21,000      1498 cc
# 1273       Honda       City  Zx Cvt Petrol     Rs. 14,31,000      1497 cc
# 1274       Honda       City   V Cvt Petrol     Rs. 12,01,000      1497 cc
# 1275  Mitsubishi    Montero         3.2 At     Rs. 68,62,560      3200 cc
#
#       Cylinders  Valves_Per_Cylinder               Drivetrain  \
# ...

# %%
data=pd.read_csv("cars.csv practice")

# %%
data.head()
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
data.isnull()
# Out:
#        Make  Model  Variant  Ex-Showroom_Price  Displacement  Cylinders  \
# 0     False  False    False              False         False      False
# 1     False  False    False              False         False      False
# 2     False  False    False              False         False      False
# 3     False  False    False              False         False      False
# 4     False  False    False              False         False      False
# ...     ...    ...      ...                ...           ...        ...
# 1271  False  False    False              False         False      False
# 1272  False  False    False              False         False      False
# 1273  False  False    False              False         False      False
# 1274  False  False    False              False         False      False
# 1275  False  False    False              False         False      False
#
#       Valves_Per_Cylinder  Drivetrain  Cylinder_Configuration  Emission_Norm  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Columns: 140 entries, Make to Electric_Range
# dtypes: float64(6), object(134)
# memory usage: 1.4+ MB

# %%
data.isnull().sum()
# Out:
# Make                   75
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
# Displacement           12
#                      ...
# USB_Ports            1247
# Heads-Up_Display     1225
# Welcome_Lights       1207
# Battery              1263
# Electric_Range       1259
# Length: 140, dtype: int64

# %%
data.head(1)
# Out:
#    Make      Model Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx      Xt      Rs. 2,92,667       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# 0         BS IV  ...                      NaN                 NaN         NaN
#
#   ASR_/_Traction_Control Cruise_Control USB_Ports Heads-Up_Display  \
# 0                    NaN            NaN       NaN              NaN
#
#   Welcome_Lights  Battery Electric_Range
# 0            NaN      NaN            NaN
#
# [1 rows x 140 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Columns: 140 entries, Make to Electric_Range
# dtypes: float64(6), object(134)
# memory usage: 1.4+ MB

# %%
data.describe()
# Out:
#          Cylinders  Valves_Per_Cylinder        Doors  Seating_Capacity  \
# count  1210.000000          1174.000000  1272.000000       1270.000000
# mean      4.380992             3.977853     4.550314          5.270079
# std       1.660957             0.833763     0.747816          1.145231
# min       2.000000             1.000000     2.000000          2.000000
# 25%       4.000000             4.000000     4.000000          5.000000
# 50%       4.000000             4.000000     5.000000          5.000000
# 75%       4.000000             4.000000     5.000000          5.000000
# max      16.000000            16.000000     5.000000         16.000000
#
#        Number_of_Airbags  USB_Ports
# count        1141.000000  29.000000
# mean            3.787029   1.793103
# std             2.522399   0.773642
# min             1.000000   1.000000
# 25%             2.000000   1.000000
# 50%             2.000000   2.000000
# 75%             6.000000   2.000000
# ...

# %%
data['Make'].unique
# Out:
# <bound method Series.unique of 0             Tata
# 1             Tata
# 2             Tata
# 3             Tata
# 4             Tata
#            ...
# 1271         Honda
# 1272         Honda
# 1273         Honda
# 1274         Honda
# 1275    Mitsubishi
# Name: Make, Length: 1276, dtype: object>

# %%
data['Make'].value_counts()
# Out:
# Make
# Maruti Suzuki       149
# Hyundai             130
# Mahindra            119
# Tata                100
# Toyota               82
# Honda                64
# Ford                 43
# Skoda                43
# Bmw                  37
# Renault              36
# Volkswagen           34
# Audi                 31
# Nissan               29
# Jeep                 28
# Land Rover Rover     27
# Fiat                 23
# Jaguar               22
# Kia                  21
# Volvo                18
# Datsun               15
# Maruti Suzuki R      14
# Porsche              14
# Mg                   13
# Lamborghini          13
# Icml                 11
# Mini                 10
# Land Rover           10
# Lexus                10
# Maserati              9
# Ferrari               8
# Mitsubishi            7
# Premier               6
# Bentley               6
# Force                 6
# Isuzu                 5
# Aston Martin          3
# Bugatti               2
# Bajaj                 2
# ...

# %%
data['USB_Ports']=data['USB_Ports'].fillna(data['USB_Ports'].mean())

# %%
data['Make']=data['Make'].fillna('Maruti Suzuki ',inplace=False)

# %%
data.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
# Displacement           12
#                      ...
# USB_Ports               0
# Heads-Up_Display     1225
# Welcome_Lights       1207
# Battery              1263
# Electric_Range       1259
# Length: 140, dtype: int64

# %%
data['Make'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Make'].unique()
# Out:
# array(['Tata', 'Datsun', 'Renault', 'Maruti Suzuki', 'Hyundai', 'Premier',
#        'Toyota', 'Nissan', 'Volkswagen', 'Ford', 'Mahindra', 'Fiat',
#        'Honda', 'Jeep', 'Isuzu', 'Skoda', 'Audi', 'Maruti Suzuki ', 'Dc',
#        'Mini', 'Volvo', 'Jaguar', 'Bmw', 'Land Rover', 'Porsche', 'Lexus',
#        'Maserati', 'Lamborghini', 'Bentley', 'Ferrari', 'Aston Martin',
#        'Bugatti', 'Bajaj', 'Icml', 'Force', 'Mg', 'Kia',
#        'Land Rover Rover', 'Mitsubishi', 'Maruti Suzuki R'], dtype=object)

# %%
data['Make'].value_counts()
# Out:
# Make
# Maruti Suzuki       149
# Hyundai             130
# Mahindra            119
# Tata                100
# Toyota               82
# Maruti Suzuki        75
# Honda                64
# Skoda                43
# Ford                 43
# Bmw                  37
# Renault              36
# Volkswagen           34
# Audi                 31
# Nissan               29
# Jeep                 28
# Land Rover Rover     27
# Fiat                 23
# Jaguar               22
# Kia                  21
# Volvo                18
# Datsun               15
# Maruti Suzuki R      14
# Porsche              14
# Mg                   13
# Lamborghini          13
# Icml                 11
# Mini                 10
# Land Rover           10
# Lexus                10
# Maserati              9
# Ferrari               8
# Mitsubishi            7
# Premier               6
# Bentley               6
# Force                 6
# Isuzu                 5
# Aston Martin          3
# Bugatti               2
# ...

# %%
data.head()
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Columns: 140 entries, Make to Electric_Range
# dtypes: float64(6), object(134)
# memory usage: 1.4+ MB

# %%
data.shape
# Out:
# (1276, 140)

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Variant', 'Ex-Showroom_Price', 'Displacement',
#        'Cylinders', 'Valves_Per_Cylinder', 'Drivetrain',
#        'Cylinder_Configuration', 'Emission_Norm',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=140)

# %%
data.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
# Displacement           12
#                      ...
# USB_Ports               0
# Heads-Up_Display     1225
# Welcome_Lights       1207
# Battery              1263
# Electric_Range       1259
# Length: 140, dtype: int64

# %%
data['Heads-Up_Display'].unique()
# Out:
# array([nan, 'Yes'], dtype=object)

# %%
data['Heads-Up_Display'].value_counts()
# Out:
# Heads-Up_Display
# Yes    51
# Name: count, dtype: int64

# %%
data['Heads-Up_Display'].fillna('yes', inplace=True)
# Out:
# C:\Users\abbas\AppData\Local\Temp\ipykernel_19372\3659487814.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Heads-Up_Display'].fillna('yes', inplace=True)

# %%
data['Heads-Up_Display'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Make']=data['Make'].fillna('Maruti Suzuki ',inplace=False)

# %%
data.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
# Displacement           12
#                      ...
# USB_Ports               0
# Heads-Up_Display        0
# Welcome_Lights       1207
# Battery              1263
# Electric_Range       1259
# Length: 140, dtype: int64

# %%
data['Welcome_Lights'].unique()
# Out:
# array([nan, 'Yes'], dtype=object)

# %%
data['Welcome_Lights'].value_counts()
# Out:
# Welcome_Lights
# Yes    69
# Name: count, dtype: int64

# %%
data['Welcome_Lights'].fillna('yes',inplace=True)
# Out:
# C:\Users\abbas\AppData\Local\Temp\ipykernel_19372\1256795697.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Welcome_Lights'].fillna('yes',inplace=True)

# %%
data['Welcome_Lights'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Battery'].unique()
# Out:
# array([nan, '210 ampere-hour', '21.5 kWh,Battery Placed Under Rear Seats',
#        '200 ampere-hour', '44.5 (kWh), Lithium Ion',
#        '30.2 kWh* Advanced Li-ion polymer, liquid cooled battery pack with IP67 certification'],
#       dtype=object)

# %%
data['Battery'].value_counts()
# Out:
# Battery
# 21.5 kWh,Battery Placed Under Rear Seats                                                 3
# 30.2 kWh* Advanced Li-ion polymer, liquid cooled battery pack with IP67 certification    3
# 200 ampere-hour                                                                          3
# 210 ampere-hour                                                                          2
# 44.5 (kWh), Lithium Ion                                                                  2
# Name: count, dtype: int64

# %%
data['Battery'].fillna('200 ampere-hour',inplace=True)
# Out:
# C:\Users\abbas\AppData\Local\Temp\ipykernel_19372\2790763518.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Battery'].fillna('200 ampere-hour',inplace=True)

# %%
data['Battery'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Displacement'].unique()
# Out:
# array(['624 cc', '799 cc', '999 cc', '1196 cc', '998 cc', '1198 cc',
#        '1086 cc', '1199 cc', '1197 cc', '1173 cc', '1489 cc', '1248 cc',
#        '1364 cc', '1193 cc', '1396 cc', '1186 cc', '1498 cc', '1194 cc',
#        '1496 cc', '1461 cc', '1368 cc', '1956 cc', '2999 cc', '2157 cc',
#        '1968 cc', '1997 cc', '1597 cc', '1798 cc', '1395 cc', '1595 cc',
#        '2143 cc', '1991 cc', '2000 cc', '1998 cc', '1969 cc', '1999 cc',
#        '1984 cc', '1995 cc', '2995 cc', '2993 cc', '2998 cc', '4951 cc',
#        '2987 cc', '6417 cc', '3604 cc', '2996 cc', '2979 cc', '1988 cc',
#        '5461 cc', '2982 cc', '3456 cc', '2894 cc', '6592 cc', '3982 cc',
#        '2925 cc', '4691 cc', '5980 cc', '4663 cc', '3996 cc', '4461 cc',
#        '5204 cc', '5998 cc', '3855 cc', '5950 cc', '5198 cc', '4497 cc',
#        '6593 cc', '6752 cc', '6750 cc', '6749 cc', '7993 cc', '216 cc',
#        '796 cc', '1120 cc', '1497 cc', '1994 cc', '1298 cc', '1397 cc',
# ...

# %%
data['Displacement'].value_counts()
# Out:
# Displacement
# 1197 cc    108
# 1498 cc     87
# 1248 cc     62
# 1198 cc     58
# 1497 cc     56
#           ...
# 1993 cc      1
# 5700 cc      1
# 1047 cc      1
# 2200 cc      1
# 3200 cc      1
# Name: count, Length: 129, dtype: int64

# %%
data['Electric_Range'].unique()
# Out:
# array([nan, '39.53 km/full charge', '110 km/full charge',
#        '213 km/full charge', '340 km/full charge', '11.68 km/full charge',
#        '312 km/full charge', '300 km/full charge', '462 km/full charge'],
#       dtype=object)

# %%
data['Electric_Range'].value_counts()
# Out:
# Electric_Range
# 110 km/full charge      5
# 213 km/full charge      3
# 340 km/full charge      2
# 11.68 km/full charge    2
# 312 km/full charge      2
# 39.53 km/full charge    1
# 300 km/full charge      1
# 462 km/full charge      1
# Name: count, dtype: int64

# %%
data['Electric_Range'].fillna(method='ffill',inplace=True)
# Out:
# C:\Users\abbas\AppData\Local\Temp\ipykernel_19372\3365196243.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Electric_Range'].fillna(method='ffill',inplace=True)
# C:\Users\abbas\AppData\Local\Temp\ipykernel_19372\3365196243.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['Electric_Range'].fillna(method='ffill',inplace=True)

# %%
data['Electric_Range'].isnull().sum()
# Out:
# np.int64(319)

# %%
data.isnull().sum()
# Out:
# Make                   0
# Model                  0
# Variant                0
# Ex-Showroom_Price      0
# Displacement          12
#                     ...
# USB_Ports              0
# Heads-Up_Display       0
# Welcome_Lights         0
# Battery                0
# Electric_Range       319
# Length: 140, dtype: int64

# %%
data.head()
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %%
data['Leather_Wrapped_Steering'].unique()
# Out:
# array([nan, 'Yes'], dtype=object)

# %%
data['Leather_Wrapped_Steering'].value_counts()
# Out:
# Leather_Wrapped_Steering
# Yes    587
# Name: count, dtype: int64

# %%
data['Leather_Wrapped_Steering'].fillna('yes ',inplace=True)
# Out:
# C:\Users\abbas\AppData\Local\Temp\ipykernel_19372\2250075964.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Leather_Wrapped_Steering'].fillna('yes ',inplace=True)

# %%
data['Leather_Wrapped_Steering'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Automatic_Headlamps'].unique()
# Out:
# array([nan, 'Yes'], dtype=object)

# %%
data['Automatic_Headlamps'].value_counts()
# Out:
# Automatic_Headlamps
# Yes    502
# Name: count, dtype: int64

# %%
data['Automatic_Headlamps'].fillna('yes ',inplace=True)
# Out:
# C:\Users\abbas\AppData\Local\Temp\ipykernel_19372\1276874225.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Automatic_Headlamps'].fillna('yes ',inplace=True)

# %%
data['Automatic_Headlamps'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Engine_Type'].unique()
# Out:
# array([nan, '2.0 Diesel',
#        'Roller cam follower, continuous intake and exhaust camshaft adjustment, hydraulic valve-play compensation / 2/2 inlet/exhaust valves per cylinder',
#        '1.2 L Revotron (BS VI)', '1.5L Turbocharged Revotorq (BS VI)',
#        'Revotron 1.2 L, BS6 Engine', 'M1 Category', 'CRDi', 'D180',
#        'P 250', 'Biturbo engine', '9G-TRONIC'], dtype=object)

# %%
data['Engine_Type'].value_counts().sum()
# Out:
# np.int64(34)

# %%
data['Engine_Type'].fillna(method='bfill',inplace=True)
# Out:
# C:\Users\abbas\AppData\Local\Temp\ipykernel_19372\4150238755.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Engine_Type'].fillna(method='bfill',inplace=True)
# C:\Users\abbas\AppData\Local\Temp\ipykernel_19372\4150238755.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['Engine_Type'].fillna(method='bfill',inplace=True)

# %%
data['Engine_Type'].isnull().sum()
# Out:
# np.int64(227)

# %%
data.isnull().any()
# Out:
# Make                 False
# Model                False
# Variant              False
# Ex-Showroom_Price    False
# Displacement          True
#                      ...
# USB_Ports            False
# Heads-Up_Display     False
# Welcome_Lights       False
# Battery              False
# Electric_Range        True
# Length: 140, dtype: bool

# %%
data['Displacement'].fillna('624cc',inplace=True )
# Out:
# C:\Users\abbas\AppData\Local\Temp\ipykernel_19372\922598848.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Displacement'].fillna('624cc',inplace=True )

# %%
data['Displacement'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['ASR_/_Traction_Control'].unique()
# Out:
# array([nan, 'Yes'], dtype=object)

# %%
data['ASR_/_Traction_Control'].value_counts()
# Out:
# ASR_/_Traction_Control
# Yes    442
# Name: count, dtype: int64

# %%
data['ASR_/_Traction_Control'].fillna(method='bfill',inplace=True )
# Out:
# C:\Users\abbas\AppData\Local\Temp\ipykernel_19372\1161863675.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['ASR_/_Traction_Control'].fillna(method='bfill',inplace=True )
# C:\Users\abbas\AppData\Local\Temp\ipykernel_19372\1161863675.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['ASR_/_Traction_Control'].fillna(method='bfill',inplace=True )

# %%
data['ASR_/_Traction_Control'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Cruise_Control'].unique()
# Out:
# array([nan, 'Yes'], dtype=object)

# %%
data['Cruise_Control'].fillna(method='bfill',inplace=True )
# Out:
# C:\Users\abbas\AppData\Local\Temp\ipykernel_19372\1553576079.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Cruise_Control'].fillna(method='bfill',inplace=True )
# C:\Users\abbas\AppData\Local\Temp\ipykernel_19372\1553576079.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['Cruise_Control'].fillna(method='bfill',inplace=True )

# %%
data['Cruise_Control'].isnull().sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
# Out:
# Make                   0
# Model                  0
# Variant                0
# Ex-Showroom_Price      0
# Displacement           0
#                     ...
# USB_Ports              0
# Heads-Up_Display       0
# Welcome_Lights         0
# Battery                0
# Electric_Range       319
# Length: 140, dtype: int64
